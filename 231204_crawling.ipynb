# %% [markdown]
# ### 데싱디바 사이트 한 페이지 이미지 링크 추출

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

#### 1. "데싱디바 > SHOP > 네일 > 전체 페이지"에서 제품별 URL 크롤링 ####
url = 'https://dashingdiva.co.kr/category/%EB%84%A4%EC%9D%BC/82/?page=1'
response = requests.get(url, headers=headers)  # 요청

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "lxml")
#     print(soup)
    
    prdImg = soup.select('div.thumbnail > div > a[href]')
    print(len(prdImg))           # 한 페이지 당 24개 제품
    
    for img_link in prdImg:
        href = img_link['href']  # 이미지 링크 추출
        print(href)              # 주소 앞에 'https://dashingdiva.co.kr' 붙여주기 
        
else:
    print('페이지를 가져올 수 없습니다.')
# Out:
# 24
# /product/매직프레스-해피-크리스마스레귤러-라운드/7883/category/82/display/1/
# /product/매직프레스-플러스-블랙홀코핀/6874/category/82/display/1/
# /product/글레이즈-21-best-네일젤네일-33/7466/category/82/display/1/
# /product/매직프레스-클라우디-베어숏-스퀘어/7278/category/82/display/1/
# /product/매직프레스-메리-루돌프레귤러-라운드/7881/category/82/display/1/
# /product/매직프레스-멜로우-스노우레귤러-라운드/7870/category/82/display/1/
# /product/매직프레스-웨딩-링롱-오발/3873/category/82/display/1/
# /product/매직프레스-쉬머-퀼팅아몬드/7894/category/82/display/1/
# /product/글레이즈-홀리데이-무드/7934/category/82/display/1/
# /product/매직프레스-스노우-플라워레귤러-라운드/7868/category/82/display/1/
# /product/매직프레스-러브-로지레귤러-라운드/6813/category/82/display/1/
# /product/매직프레스-두-낫-디스터브코핀/6080/category/82/display/1/
# /product/글레이즈-모브-버건디/7347/category/82/display/1/
# /product/매직프레스-위드-러브레귤러-스퀘어/537/category/82/display/1/
# /product/매직프레스-오로라-드림레귤러-라운드/6666/category/82/display/1/
# /product/매직프레스-크리스탈-드롭레귤러-라운드/7136/category/82/display/1/
# /product/매직프레스-플러스-오아시스코핀/6873/category/82/display/1/
# /product/매직프레스-체크-워머코핀/7871/category/82/display/1/
# /product/글레이즈-애프터글로우/7433/category/82/display/1/
# /product/매직프레스-피스-러브-해피니스코핀/6078/category/82/display/1/
# /product/매직프레스-누드-글로시아몬드/7927/category/82/display/1/
# /product/매직프레스-샤인-플럼코핀/5506/category/82/display/1/
# /product/매직프레스-드리미-블랙코핀/7912/category/82/display/1/
# /product/매직프레스-웨딩-세레모니레귤러-라운드/6085/category/82/display/1/

# %% [markdown]
# ### 데싱디바 사이트 전체 페이지 이미지 링크 추출

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
all_product_urls = []    # 전체 제품 링크 저장할 리스트

### 1~8 한 페이지씩 방문 ###
for i in range(1,9):
    url = f'https://dashingdiva.co.kr/category/%EB%84%A4%EC%9D%BC/82/?page={i}'    
    
    ## 이미지 링크 크롤링
    response = requests.get(url, headers=headers)    # request 요청

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "lxml")
        prdImg = soup.select('div.thumbnail > div > a')
        print(f'{i}번째 페이지 제품 수 :',len(prdImg)) # 페이지 당 제품 수
        
        # 이미지 링크 추출
        for img_link in prdImg:
            href = img_link['href']  
            href = 'https://dashingdiva.co.kr' + href
            all_product_urls.append(href)  # 이미지 링크 리스트에 추가

    else:
        print('페이지를 가져올 수 없습니다.')
     
print()    
print(f'총 제품 수는 {len(all_product_urls)}')
print('============== 제품 urls ==============')
print(all_product_urls[:3])
# Out:
# 1번째 페이지 제품 수 : 24
# 2번째 페이지 제품 수 : 24
# 3번째 페이지 제품 수 : 24
# 4번째 페이지 제품 수 : 24
# 5번째 페이지 제품 수 : 24
# 6번째 페이지 제품 수 : 24
# 7번째 페이지 제품 수 : 24
# 8번째 페이지 제품 수 : 5
#
# 총 제품 수는 173
# ============== 제품 urls ==============
# ['https://dashingdiva.co.kr/product/매직프레스-해피-크리스마스레귤러-라운드/7883/category/82/display/1/', 'https://dashingdiva.co.kr/product/매직프레스-플러스-블랙홀코핀/6874/category/82/display/1/', 'https://dashingdiva.co.kr/product/글레이즈-21-best-네일젤네일-33/7466/category/82/display/1/']

# %% [markdown]
# ### 한 상품 정보 뽑기

# %%
url = 'https://dashingdiva.co.kr/product/%EB%A7%A4%EC%A7%81%ED%94%84%EB%A0%88%EC%8A%A4-%ED%95%B4%ED%94%BC-%ED%81%AC%EB%A6%AC%EC%8A%A4%EB%A7%88%EC%8A%A4%EB%A0%88%EA%B7%A4%EB%9F%AC-%EB%9D%BC%EC%9A%B4%EB%93%9C/7883/category/82/display/1/'

response = requests.get(url, headers=headers)    # request 요청

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "lxml")
    
    # 종류, 제품명 추출
    product_info = soup.select('div.headingArea > h2')
    if product_info:     # 리스트에 요소가 있는지 확인
        product_info_txt = product_info[0].get_text()  # 첫 번째 요소의 텍스트 추출
        product_type = product_info_txt.split(' - ')[0]
        product_name = product_info_txt.split(' - ')[1]
        print('종류 :', product_type)
        print('제품명 :', product_name)
    
    # 상세설명 추출
    summary = soup.select('span.summary')[0].get_text()
    print('상세 설명 :', summary)
    
    # 키워드 추출
    keywords = soup.select('div.headingArea > div.simple')[0].get_text()
    print('키워드 :', keywords)
    
    # 상품코드 추출
    product_code = soup.select('div.infoArea tr:nth-child(7) > td > span')[0].get_text()
    print('상품코드 :', product_code)
    
    # 상품 가격 추출
    product_price = soup.select('div.price-box > ul > li.prd-price')[0].get_text()
    print('상품 가격 :', product_price)

else:
    print('페이지를 가져올 수 없습니다.')
# Out:
# 종류 : 매직프레스
# 제품명 : 해피 크리스마스(레귤러 라운드)
# 상세 설명 : 산타와 루돌프 디자인으로 크리스마스 분위기 물씬 나는 네일
# 키워드 : 늘이농PICK,23.11 출시,크리스마스,3D엠보,루돌프,산타
# 상품코드 : MDR3W029RR
# 상품 가격 : 10,800원

# %% [markdown]
# ### 전체 상품 정보 뽑기

# %%
import requests
from bs4 import BeautifulSoup

product_types = []
product_names = []
summary_lst = []
keywords_lst = []
product_codes = []
product_prices = []

for idx, url in enumerate(all_product_urls):
    response = requests.get(url, headers=headers)    # request 요청
    print(f'========== {idx}번째 크롤링 시작 ==========')
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "lxml")

        # 종류, 제품명 추출
        product_info = soup.select('div.headingArea > h2')
        if product_info:     # 리스트에 요소가 있는지 확인
            product_info_txt = product_info[0].get_text()  # 첫 번째 요소의 텍스트 추출
            product_type = product_info_txt.split('-')[0]
            product_name = product_info_txt.split('-')[1]
            product_types.append(product_type.strip())
            product_names.append(product_name.strip())
        else:
            product_types.append(None)
            product_names.append(None)

        # 상세설명 추출
        summary = soup.select('span.summary')
        if summary:
            summary = summary[0].get_text()
            summary_lst.append(summary)
        else:
            summary_lst.append(None)

        # 키워드 추출
        keywords = soup.select('div.headingArea > div.simple')
        keywords = keywords[0].get_text()
        keywords_lst.append(keywords)
            
        # 상품 코드 추출
        if len(keywords)==0:
            product_code = soup.select('div.infoArea tr:nth-child(6) > td > span')
            if product_code:
                product_code = product_code[0].get_text()
                product_codes.append(product_code)
            else:
                product_codes.append(None)
        else:        
            product_code = soup.select('div.infoArea tr:nth-child(7) > td > span')
            if product_code:
                product_code = product_code[0].get_text()
                product_codes.append(product_code)
            else:
                product_codes.append(None)

        # 상품 가격 추출
        product_price = soup.select('div.price-box > ul > li.prd-price')
        if product_price:
            product_price = product_price[0].get_text()
            product_prices.append(product_price[:-1])
        else:
            product_prices.append(None)

    else:
        print('페이지를 가져올 수 없습니다.')
# Out:
# ========== 0번째 크롤링 시작 ==========
# ========== 1번째 크롤링 시작 ==========
# ========== 2번째 크롤링 시작 ==========
# ========== 3번째 크롤링 시작 ==========
# ========== 4번째 크롤링 시작 ==========
# ========== 5번째 크롤링 시작 ==========
# ========== 6번째 크롤링 시작 ==========
# ========== 7번째 크롤링 시작 ==========
# ========== 8번째 크롤링 시작 ==========
# ========== 9번째 크롤링 시작 ==========
# ========== 10번째 크롤링 시작 ==========
# ========== 11번째 크롤링 시작 ==========
# ========== 12번째 크롤링 시작 ==========
# ========== 13번째 크롤링 시작 ==========
# ========== 14번째 크롤링 시작 ==========
# ========== 15번째 크롤링 시작 ==========
# ========== 16번째 크롤링 시작 ==========
# ========== 17번째 크롤링 시작 ==========
# ========== 18번째 크롤링 시작 ==========
# ========== 19번째 크롤링 시작 ==========
# ========== 20번째 크롤링 시작 ==========
# ========== 21번째 크롤링 시작 ==========
# ========== 22번째 크롤링 시작 ==========
# ========== 23번째 크롤링 시작 ==========
# ========== 24번째 크롤링 시작 ==========
# ========== 25번째 크롤링 시작 ==========
# ========== 26번째 크롤링 시작 ==========
# ========== 27번째 크롤링 시작 ==========
# ========== 28번째 크롤링 시작 ==========
# ========== 29번째 크롤링 시작 ==========
# ========== 30번째 크롤링 시작 ==========
# ========== 31번째 크롤링 시작 ==========
# ========== 32번째 크롤링 시작 ==========
# ========== 33번째 크롤링 시작 ==========
# ========== 34번째 크롤링 시작 ==========
# ========== 35번째 크롤링 시작 ==========
# ========== 36번째 크롤링 시작 ==========
# ========== 37번째 크롤링 시작 ==========
# ========== 38번째 크롤링 시작 ==========
# ========== 39번째 크롤링 시작 ==========
# ========== 40번째 크롤링 시작 ==========
# ========== 41번째 크롤링 시작 ==========
# ========== 42번째 크롤링 시작 ==========
# ========== 43번째 크롤링 시작 ==========
# ========== 44번째 크롤링 시작 ==========
# ========== 45번째 크롤링 시작 ==========
# ========== 46번째 크롤링 시작 ==========
# ========== 47번째 크롤링 시작 ==========
# ========== 48번째 크롤링 시작 ==========
# ========== 49번째 크롤링 시작 ==========
# ========== 50번째 크롤링 시작 ==========
# ========== 51번째 크롤링 시작 ==========
# ========== 52번째 크롤링 시작 ==========
# ========== 53번째 크롤링 시작 ==========
# ========== 54번째 크롤링 시작 ==========
# ========== 55번째 크롤링 시작 ==========
# ========== 56번째 크롤링 시작 ==========
# ========== 57번째 크롤링 시작 ==========
# ========== 58번째 크롤링 시작 ==========
# ========== 59번째 크롤링 시작 ==========
# ========== 60번째 크롤링 시작 ==========
# ========== 61번째 크롤링 시작 ==========
# ========== 62번째 크롤링 시작 ==========
# ========== 63번째 크롤링 시작 ==========
# ========== 64번째 크롤링 시작 ==========
# ========== 65번째 크롤링 시작 ==========
# ========== 66번째 크롤링 시작 ==========
# ========== 67번째 크롤링 시작 ==========
# ========== 68번째 크롤링 시작 ==========
# ========== 69번째 크롤링 시작 ==========
# ========== 70번째 크롤링 시작 ==========
# ========== 71번째 크롤링 시작 ==========
# ========== 72번째 크롤링 시작 ==========
# ========== 73번째 크롤링 시작 ==========
# ========== 74번째 크롤링 시작 ==========
# ========== 75번째 크롤링 시작 ==========
# ========== 76번째 크롤링 시작 ==========
# ========== 77번째 크롤링 시작 ==========
# ========== 78번째 크롤링 시작 ==========
# ========== 79번째 크롤링 시작 ==========
# ========== 80번째 크롤링 시작 ==========
# ========== 81번째 크롤링 시작 ==========
# ========== 82번째 크롤링 시작 ==========
# ========== 83번째 크롤링 시작 ==========
# ========== 84번째 크롤링 시작 ==========
# ========== 85번째 크롤링 시작 ==========
# ========== 86번째 크롤링 시작 ==========
# ========== 87번째 크롤링 시작 ==========
# ========== 88번째 크롤링 시작 ==========
# ========== 89번째 크롤링 시작 ==========
# ========== 90번째 크롤링 시작 ==========
# ========== 91번째 크롤링 시작 ==========
# ========== 92번째 크롤링 시작 ==========
# ========== 93번째 크롤링 시작 ==========
# ========== 94번째 크롤링 시작 ==========
# ========== 95번째 크롤링 시작 ==========
# ========== 96번째 크롤링 시작 ==========
# ========== 97번째 크롤링 시작 ==========
# ========== 98번째 크롤링 시작 ==========
# ========== 99번째 크롤링 시작 ==========
# ========== 100번째 크롤링 시작 ==========
# ========== 101번째 크롤링 시작 ==========
# ========== 102번째 크롤링 시작 ==========
# ========== 103번째 크롤링 시작 ==========
# ========== 104번째 크롤링 시작 ==========
# ========== 105번째 크롤링 시작 ==========
# ========== 106번째 크롤링 시작 ==========
# ========== 107번째 크롤링 시작 ==========
# ========== 108번째 크롤링 시작 ==========
# ========== 109번째 크롤링 시작 ==========
# ========== 110번째 크롤링 시작 ==========
# ========== 111번째 크롤링 시작 ==========
# ========== 112번째 크롤링 시작 ==========
# ========== 113번째 크롤링 시작 ==========
# ========== 114번째 크롤링 시작 ==========
# ========== 115번째 크롤링 시작 ==========
# ========== 116번째 크롤링 시작 ==========
# ========== 117번째 크롤링 시작 ==========
# ========== 118번째 크롤링 시작 ==========
# ========== 119번째 크롤링 시작 ==========
# ========== 120번째 크롤링 시작 ==========
# ========== 121번째 크롤링 시작 ==========
# ========== 122번째 크롤링 시작 ==========
# ========== 123번째 크롤링 시작 ==========
# ========== 124번째 크롤링 시작 ==========
# ========== 125번째 크롤링 시작 ==========
# ========== 126번째 크롤링 시작 ==========
# ========== 127번째 크롤링 시작 ==========
# ========== 128번째 크롤링 시작 ==========
# ========== 129번째 크롤링 시작 ==========
# ========== 130번째 크롤링 시작 ==========
# ========== 131번째 크롤링 시작 ==========
# ========== 132번째 크롤링 시작 ==========
# ========== 133번째 크롤링 시작 ==========
# ========== 134번째 크롤링 시작 ==========
# ========== 135번째 크롤링 시작 ==========
# ========== 136번째 크롤링 시작 ==========
# ========== 137번째 크롤링 시작 ==========
# ========== 138번째 크롤링 시작 ==========
# ========== 139번째 크롤링 시작 ==========
# ========== 140번째 크롤링 시작 ==========
# ========== 141번째 크롤링 시작 ==========
# ========== 142번째 크롤링 시작 ==========
# ========== 143번째 크롤링 시작 ==========
# ========== 144번째 크롤링 시작 ==========
# ========== 145번째 크롤링 시작 ==========
# ========== 146번째 크롤링 시작 ==========
# ========== 147번째 크롤링 시작 ==========
# ========== 148번째 크롤링 시작 ==========
# ========== 149번째 크롤링 시작 ==========
# ========== 150번째 크롤링 시작 ==========
# ========== 151번째 크롤링 시작 ==========
# ========== 152번째 크롤링 시작 ==========
# ========== 153번째 크롤링 시작 ==========
# ========== 154번째 크롤링 시작 ==========
# ========== 155번째 크롤링 시작 ==========
# ========== 156번째 크롤링 시작 ==========
# ========== 157번째 크롤링 시작 ==========
# ========== 158번째 크롤링 시작 ==========
# ========== 159번째 크롤링 시작 ==========
# ========== 160번째 크롤링 시작 ==========
# ========== 161번째 크롤링 시작 ==========
# ========== 162번째 크롤링 시작 ==========
# ========== 163번째 크롤링 시작 ==========
# ========== 164번째 크롤링 시작 ==========
# ========== 165번째 크롤링 시작 ==========
# ========== 166번째 크롤링 시작 ==========
# ========== 167번째 크롤링 시작 ==========
# ========== 168번째 크롤링 시작 ==========
# ========== 169번째 크롤링 시작 ==========
# ========== 170번째 크롤링 시작 ==========
# ========== 171번째 크롤링 시작 ==========
# ========== 172번째 크롤링 시작 ==========

# %% [markdown]
# ### 데이터프레임으로 저장, to_csv

# %%
import pandas as pd
products_info = pd.DataFrame({'product_type':product_types, 'product_name':product_names,
                             'summary':summary_lst, 'keywords':keywords_lst, 
                             'product_code':product_codes, 'product_price':product_prices})

products_info.to_csv('dashingdiva.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('dashingdiva.csv')
df.info()
# summary - 실제로 없음
# keyword - 실제로 없음
# product_code - [2+1]상품은 제품코드 미포함
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_type   173 non-null    object
#  1   product_name   173 non-null    object
#  2   summary        170 non-null    object
#  3   keywords       143 non-null    object
#  4   product_code   170 non-null    object
#  5   product_price  173 non-null    object
# dtypes: object(6)
# memory usage: 8.2+ KB

# %%
df
# Out:
#     product_type              product_name  \
# 0          매직프레스         해피 크리스마스(레귤러 라운드)
# 1      매직프레스 플러스                   블랙홀(코핀)
# 2           글레이즈  [2+1]  BEST 네일(젤네일) ~33%
# 3          매직프레스            클라우디 베어(숏 스퀘어)
# 4          매직프레스           메리 루돌프(레귤러 라운드)
# ..           ...                       ...
# 168         글레이즈                    키치 스마일
# 169        매직프레스            화이트베리(레귤러 라운드)
# 170        매직프레스       [공식몰 단독] 트윙클 데이(코핀)
# 171        매직프레스                   버건디(코핀)
# 172        매직프레스               틴티드 그레이(코핀)
#
#                                         summary  \
# 0              산타와 루돌프 디자인으로 크리스마스 분위기 물씬 나는 네일
# 1    블랙 마그네틱에 풀스톤을 더해 어느 각도에서 봐도 영롱한 프리미엄 코핀 네일
# 2                                           NaN
# 3                    몽글몽글한 구름과 닮은 귀여운 3D 곰돌이 네일
# 4              루돌프와 트리 드로잉에 씬 프렌치를 매치한 크리스마스 네일
# ..                                          ...
# 168                스마일 드로잉과 체커보드 프렌치가 더해진 키치 네일
# 169                         광택이 느껴지는 핑키쉬한 시럽 네일
# 170       화려한 글리터와 크리스탈 스톤이 손끝을 빛내주는 프리미엄 파츠 네일
# 171                         매혹적인 분위기의 버건디 코핀 네일
# 172                            깔끔한 그레이 컬러 코핀 네일
#
#                                  keywords product_code product_price
# 0      늘이농PICK,23.11 출시,크리스마스,3D엠보,루돌프,산타   MDR3W029RR       10,800원
# 1                                     NaN   MOL2W047PC        9,900원
# 2    33% 할인,가을 신상 2+1,신상 네일 2개 구매 시 1종 증정          NaN       29,600원
# 3                  곰돌이네일,동물네일,구름네일,3D엠보네일   MDR3F008SS       10,800원
# 4              23.11 출시,크리스마스,3D엠보,루돌프,트리   MDR3W019RR       10,800원
# ..                                    ...          ...           ...
# 168                          프렌치,스마일,체커보드      ZMA412N       14,800원
# 169                              풀컬러,시럽네일   MDR3W052RR        9,800원
# 170                                   NaN   MDR2F087PC       14,800원
# 171            23.09 출시,풀컬러,버건디,데일리,베이직네일   MDR3F059CF        9,800원
# 172                     풀컬러,그레이,데일리,베이직네일   MDR3F069CF        9,800원
#
# [173 rows x 6 columns]

# %%
df[df.product_code.isna()]
# Out:
#    product_type              product_name summary  \
# 2          글레이즈  [2+1]  BEST 네일(젤네일) ~33%     NaN
# 26        매직프레스             [2+1] 겨울 네일 팁     NaN
# 57         글레이즈        [2+1]  겨울 젤네일 ~33%     NaN
#
#                                 keywords product_code product_price
# 2   33% 할인,가을 신상 2+1,신상 네일 2개 구매 시 1종 증정          NaN     29,600원\n
# 26  33% 할인,겨을 신상 2+1,신상 네일 2개 구매 시 1종 증정          NaN     21,600원\n
# 57   33% 할인,겨울신상 2+1,신상 네일 2개 구매 시 1종 증정          NaN     29,600원\n
